# %%
# !/use/bin/env python
# encoding:utf-8
import pandas as pd
import numpy as np
import itertools
from sklearn.model_selection import KFold  
from sklearn import svm
from sklearn.model_selection import train_test_split
import math
import easy_excel
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import *
import sklearn.ensemble
from sklearn import metrics
from sklearn.metrics import roc_curve, auc   
import sys
import re
import math
from sklearn.model_selection import GridSearchCV
import subprocess
from sklearn.utils import shuffle
import itertools
import joblib
from sklearn.feature_selection import *

# %%
def make_kmer_list(k, alphabet):
    try:
        return ["".join(e) for e in itertools.product(alphabet, repeat=k)]
    except TypeError:
        print("TypeError: k must be an inter and larger than 0, alphabet must be a string.")
        raise TypeError
    except ValueError:
        print("TypeError: k must be an inter and larger than 0")
        raise ValueError

# %%
def performance(labelArr, predictArr):
    #labelArr[i] is actual value,predictArr[i] is predict value
    TP = 0.; TN = 0.; FP = 0.; FN = 0.
    for i in range(len(labelArr)):
        if labelArr[i] == 1 and predictArr[i] == 1:
            TP += 1.
        if labelArr[i] == 1 and predictArr[i] == 0:
            FN += 1.
        if labelArr[i] == 0 and predictArr[i] == 1:
            FP += 1.
        if labelArr[i] == 0 and predictArr[i] == 0:
            TN += 1.
    if (TP + FN)==0:
        SN=0
    else:
        SN = TP/(TP + FN) #Sensitivity = TP/P  and P = TP + FN
    if (FP+TN)==0:
        SP=0
    else:
        SP = TN/(FP + TN) #Specificity = TN/N  and N = TN + FP
    if (TP+FP)==0:
        precision=0
    else:
        precision=TP/(TP+FP)
    if (TP+FN)==0:
        recall=0
    else:
        recall=TP/(TP+FN)
    GM=math.sqrt(recall*SP)
    #MCC = (TP*TN-FP*FN)/math.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))
    return precision,recall,SN,SP,GM,TP,TN,FP,FN

# %%
import os 
import numpy as np
import pandas as pd
def generating_integrated_training(file_dir,samples_size):   
    Y=[1 for e in xrange(samples_size)]
    Y2=[0 for e in xrange(samples_size)]
    Y.extend(Y2)
    X=[]
    for root, dirs, files in os.walk(file_dir):  
#         print(root) #当前目录路径  
#         print(dirs) #当前路径下所有子目录  
        for e in files:
            if re.search('predict.csv',e)!= None and re.research('human',e)!=None:
                print e
                data=pd.read_csv(root+'/'+e,header=None,index_col=False)
                data=data.values[:,2]#设置为probability:2或者predict_label:1
                X.append(data)
    
    return X,Y
X,Y=generating_integrated_training('data',1130)
X=np.array(X).T
svc = svm.SVC()
parameters = {'kernel': ['rbf'], 'C':map(lambda x:2**x,np.linspace(-2,5,28)), 'gamma':map(lambda x:2**x,np.linspace(-5,2,28))}
clf = GridSearchCV(svc, parameters, cv=10, n_jobs=12, scoring='accuracy')
clf.fit(X, Y)
C=clf.best_params_['C']
print clf.best_score_
gamma=clf.best_params_['gamma']
y_predict=cross_val_predict(svm.SVC(kernel='rbf',C=C,gamma=gamma,),X,Y,cv=10,n_jobs=12)
ACC=metrics.accuracy_score(Y,y_predict)
print ACC
# Out:
# human_knn_NB_predict.csv
# human_PCP_SVM_predict.csv
# 2RFH_RF_predict.csv
# human_PSDNP_SVM_predict.csv
# human_knn_SVM_predict.csv
# human_PSDNP_KNN_predict.csv
# 2RFH_GBDT_predict.csv
# human_RFH_XGBoost_predict.csv
# human_knn_KNN_predict.csv
# human_PSDNP_GBDT_predict.csv
# 2RFH_NB_predict.csv
# human_RFH_GBDT_predict.csv
# human_RFH_NB_predict.csv
# 2RFH_predict.csv
# human_PSDNP_RF_predict.csv
# human_knn_RF_predict.csv
# human_PCP_RF_predict.csv
# 2RFH_KNN_predict.csv
# human_PSNP_SVM_predict.csv
# human_knn_GBDT_predict.csv
# 2RFH_XGBoost_predict.csv
# human_PCP_XGBoost_predict.csv
# human_PSDNP_LR_predict.csv
# human_RFH_RF_predict.csv
# human_PCP_GBDT_predict.csv
# human_RFH_KNN_predict.csv
# human_PCP_NB_predict.csv
# human_RFH_SVM_predict.csv
# human_PCP_LR_predict.csv
# 2RFH_SVM_predict.csv
# human_PSDNP_NB_predict.csv
# human_PCP_KNN_predict.csv
# human_knn_XGBoost_predict.csv
# 2RFH_LR_predict.csv
# human_knn_predict.csv
# human_knn_LR_predict.csv
# human_RFH_LR_predict.csv
# human_PSDNP_XGBoost_predict.csv
# 0.91017699115
# 0.91017699115

# %%
import os 
import numpy as np
import pandas as pd
def generating_integrated_training(file_dir,samples_size):   
    Y=[1 for e in xrange(samples_size)]
    Y2=[0 for e in xrange(samples_size)]
    Y.extend(Y2)
    X1=[]
    X2=[]
    X3=[]
    X4=[]
    X5=[]
    X6=[]
    X7=[]
    for root, dirs, files in os.walk(file_dir):  
#         print(root) #当前目录路径  
#         print(dirs) #当前路径下所有子目录  
        for e in files:
            if re.search('thaliana_RFH_',e)!= None:
                print e
                data=pd.read_csv(root+'/'+e,header=None,index_col=False)
                data=data.values[:,2]#设置为probability:2或者predict_label:1
                X1.append(data)
            if re.search('thaliana_PseDNC_',e)!= None:
                print e
                data=pd.read_csv(root+'/'+e,header=None,index_col=False)
                data=data.values[:,2]#设置为probability:2或者predict_label:1
                X2.append(data)
            if re.search('thaliana_PSDNP_',e)!= None:
                print e
                data=pd.read_csv(root+'/'+e,header=None,index_col=False)
                data=data.values[:,2]#设置为probability:2或者predict_label:1
                X3.append(data)
            if re.search('thaliana_PCP_',e)!= None:
                print e
                data=pd.read_csv(root+'/'+e,header=None,index_col=False)
                data=data.values[:,2]#设置为probability:2或者predict_label:1
                X4.append(data)
            if re.search('thaliana_knn_',e)!= None:
                print e
                data=pd.read_csv(root+'/'+e,header=None,index_col=False)
                data=data.values[:,2]#设置为probability:2或者predict_label:1
                X5.append(data)
            if re.search('thaliana_4_mer_',e)!= None:
                print e
                data=pd.read_csv(root+'/'+e,header=None,index_col=False)
                data=data.values[:,2]#设置为probability:2或者predict_label:1
                X6.append(data)
            if re.search('2RFH_',e)!= None:
                print e
                data=pd.read_csv(root+'/'+e,header=None,index_col=False)
                data=data.values[:,2]#设置为probability:2或者predict_label:1
                X7.append(data)
    X=[]
    X=[np.array(X1).T,np.array(X2).T,np.array(X3).T,np.array(X4).T,np.array(X5).T,np.array(X6).T,np.array(X7).T]
    return X,Y
X_,Y=generating_integrated_training('/home02/chenhuangrong/probability_model_data',394)

for X1_index in np.arange(0,1,0.01):
    for X2_index in np.arange(0,1-X1_index,0.01):
        for X3_index in np.arange(0,1-X1_index-X2_index,0.01):
            for X4_index in np.arange(0,1-X1_index-X2_index-X3_index,0.01):
                for X5_index in np.arange(0,1-X1_index-X2_index-X3_index-X4_index,0.01):
                    for X6_index in np.arange(0,1-X1_index-X2_index-X3_index-X4_index-X5_index,0.01):
                        X7=1-X1_index-X2_index-X3_index-X4_index-X5_index-X6_index
                        X=X1_index*X_[0]+X2_index*X_[1]+X3_index*X_[2]+X4_index*X_[3]+X5_index*X_[4]+X6_index*X_[5]+X7_index*X_[6]
                        svc = svm.SVC()
                        parameters = {'kernel': ['rbf'], 'C':map(lambda x:2**x,np.linspace(-2,5,28)), 'gamma':map(lambda x:2**x,np.linspace(-5,2,28))}
                        clf = GridSearchCV(svc, parameters, cv=10, n_jobs=12, scoring='accuracy')
                        clf.fit(X, Y)
                        C=clf.best_params_['C']
                        print clf.best_score_
                        gamma=clf.best_params_['gamma']
                        y_predict=cross_val_predict(svm.SVC(kernel='rbf',C=C,gamma=gamma,),X,Y,cv=10,n_jobs=12)
                        ACC=metrics.accuracy_score(Y,y_predict)
                        print ACC
# Out:
# thaliana_PCP_XGBoost_predict.csv
# thaliana_knn_NB_predict.csv
# thaliana_PseDNC_LR_predict.csv
# thaliana_PSDNP_GBDT_predict.csv
# thaliana_RFH_GBDT_predict.csv
# thaliana_4_mer_NB_predict.csv
# 2RFH_RF_predict.csv
# thaliana_PCP_RF_predict.csv
# thaliana_PSDNP_KNN_predict.csv
# thaliana_4_mer_GBDT_predict.csv
# thaliana_PCP_KNN_predict.csv
# thaliana_4_mer_LR_predict.csv
# thaliana_RFH_XGBoost_predict.csv
# 2RFH_GBDT_predict.csv
# thaliana_PSDNP_RF_predict.csv
# thaliana_PSDNP_XGBoost_predict.csv
# thaliana_PSDNP_SVM_predict.csv
# thaliana_4_mer_KNN_predict.csv
# 2RFH_NB_predict.csv
# thaliana_knn_RF_predict.csv
# thaliana_PCP_SVM_predict.csv
# thaliana_PseDNC_GBDT_predict.csv
# thaliana_PCP_LR_predict.csv
# thaliana_PCP_GBDT_predict.csv
# thaliana_RFH_RF_predict.csv
# thaliana_PseDNC_KNN_predict.csv
# thaliana_knn_XGBoost_predict.csv
# thaliana_knn_SVM_predict.csv
# thaliana_RFH_LR_predict.csv
# thaliana_4_mer_SVM_predict.csv
# thaliana_PSDNP_NB_predict.csv
# 2RFH_KNN_predict.csv
# thaliana_PseDNC_SVM_predict.csv
# thaliana_RFH_SVM_predict.csv
# thaliana_RFH_KNN_predict.csv
# 2RFH_XGBoost_predict.csv
# thaliana_4_mer_XGBoost_predict.csv
# thaliana_PSDNP_LR_predict.csv
# thaliana_knn_KNN_predict.csv
# thaliana_knn_GBDT_predict.csv
# 2RFH_SVM_predict.csv
# thaliana_4_mer_RF_predict.csv
# thaliana_PseDNC_NB_predict.csv
# 2RFH_LR_predict.csv
# thaliana_PseDNC_XGBoost_predict.csv
# thaliana_PCP_NB_predict.csv
# thaliana_PseDNC_RF_predict.csv
# thaliana_knn_LR_predict.csv
# thaliana_RFH_NB_predict.csv
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.841370558376
# 0.841370558376
# 0.840101522843
# 0.840101522843
# 0.835025380711
# 0.835025380711
# 0.831218274112
# 0.831218274112
# 0.82614213198
# 0.82614213198
# 0.821065989848
# 0.821065989848
# 0.819796954315
# 0.819796954315
# 0.819796954315
# 0.819796954315
# 0.817258883249
# 0.817258883249
# 0.815989847716
# 0.815989847716
# 0.814720812183
# 0.814720812183
# 0.814720812183
# 0.814720812183
# 0.81345177665
# 0.81345177665
# 0.812182741117
# 0.812182741117
# 0.812182741117
# 0.812182741117
# 0.812182741117
# 0.812182741117
# 0.812182741117
# 0.812182741117
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.810913705584
# 0.840101522843
# 0.840101522843
# 0.842639593909
# 0.842639593909
# 0.843908629442
# 0.843908629442
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.841370558376
# 0.841370558376
# 0.841370558376
# 0.841370558376
# 0.841370558376
# 0.841370558376
# 0.841370558376
# 0.841370558376
# 0.840101522843
# 0.840101522843
# 0.840101522843
# 0.840101522843
# 0.837563451777
# 0.837563451777
# 0.837563451777
# 0.837563451777
# 0.837563451777
# 0.837563451777
# 0.837563451777
# 0.837563451777
# 0.837563451777
# 0.837563451777
# 0.836294416244
# 0.836294416244
# 0.835025380711
# 0.835025380711
# 0.835025380711
# 0.835025380711
# 0.835025380711
# 0.835025380711
# 0.835025380711
# 0.835025380711
# 0.835025380711
# 0.835025380711
# 0.835025380711
# 0.835025380711
# 0.835025380711
# 0.835025380711
# 0.833756345178
# 0.833756345178
# 0.833756345178
# 0.833756345178
# 0.833756345178
# 0.833756345178
# 0.832487309645
# 0.832487309645
# 0.831218274112
# 0.831218274112
# 0.831218274112
# 0.831218274112
# 0.831218274112
# 0.831218274112
# 0.831218274112
# 0.831218274112
# 0.829949238579
# 0.829949238579
# 0.828680203046
# 0.828680203046
# 0.827411167513
# 0.827411167513
# 0.827411167513
# 0.827411167513
# 0.828680203046
# 0.828680203046
# 0.828680203046
# 0.828680203046
# 0.828680203046
# 0.828680203046
# 0.828680203046
# 0.828680203046
# 0.82614213198
# 0.82614213198
# 0.822335025381
# 0.822335025381
# 0.819796954315
# 0.819796954315
# 0.818527918782
# 0.818527918782
# 0.818527918782
# 0.818527918782
# 0.819796954315
# 0.819796954315
# 0.818527918782
# 0.818527918782
# 0.817258883249
# 0.817258883249
# 0.817258883249
# 0.817258883249
# 0.817258883249
# 0.817258883249
# 0.818527918782
# 0.818527918782
# 0.819796954315
# 0.819796954315
# 0.819796954315
# 0.819796954315
# 0.819796954315
# 0.819796954315
# 0.818527918782
# 0.818527918782
# 0.817258883249
# 0.817258883249
# 0.817258883249
# 0.817258883249
# 0.817258883249
# 0.817258883249
# 0.815989847716
# 0.815989847716
# 0.815989847716
# 0.815989847716
# 0.817258883249
# 0.817258883249
# 0.817258883249
# 0.817258883249
# 0.817258883249
# 0.817258883249
# 0.817258883249
# 0.817258883249
# 0.817258883249
# 0.817258883249
# 0.817258883249
# 0.817258883249
# 0.817258883249
# 0.817258883249
# 0.815989847716
# 0.815989847716
# 0.815989847716
# 0.815989847716
# 0.814720812183
# 0.814720812183
# 0.814720812183
# 0.814720812183
# 0.814720812183
# 0.814720812183
# 0.814720812183
# 0.814720812183
# 0.815989847716
# 0.815989847716
# 0.81345177665
# 0.81345177665
# 0.81345177665
# 0.81345177665
# 0.812182741117
# 0.812182741117
# 0.81345177665
# 0.81345177665
# 0.81345177665
# 0.81345177665
# 0.837563451777
# 0.837563451777
# 0.840101522843
# 0.840101522843
# 0.840101522843
# 0.840101522843
# 0.842639593909
# 0.842639593909
# 0.843908629442
# 0.843908629442
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.842639593909
# 0.843908629442
# 0.843908629442
# 0.842639593909
# 0.842639593909
