# %%
import HeatMap
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-6a237a034157> in <module>()
# ----> 1 import HeatMap
#
# ImportError: No module named HeatMap
