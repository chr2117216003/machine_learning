# %%
from sklearn import svm
import numpy as np
import pandas as pd
import math
import easy_excel
from sklearn.model_selection import *
import sklearn.ensemble
from sklearn import metrics
import sys
from sklearn.model_selection import GridSearchCV

# %%
from sklearn import svm
import numpy as np
import pandas as pd
import math
import easy_excel
from sklearn.model_selection import *
import sklearn.ensemble
from sklearn import metrics
import sys
from sklearn.model_selection import GridSearchCV
def svm_crossvalidation():
    if __name__=='__main__':
        datapath ="/home01/chenhuangrong/ROC/RFH_feature.csv"
        train_data = pd.read_csv(datapath, header=None, index_col=None)
        X = np.array(train_data)
        Y = list(map(lambda x: 1, xrange(len(train_data) / 2)))
        Y2 = list(map(lambda x: 0, xrange(len(train_data) / 2)))
        Y.extend(Y2)
        Y = np.array(Y)
        svc = svm.SVC()
#         parameters = {'kernel':['rbf'], 'C': np.linspace(2,5,2), 'gamma': np.linspace(2,5,2)}
        parameters = {'kernel': ['rbf'], 'C':np.logspace(-5,15,20,base=2), 'gamma': np.logspace(-15,5,20,base=2)}
        clf = GridSearchCV(svc, parameters, cv=10, n_jobs=-1, scoring='roc_auc')
        clf.fit(X, Y)
        C=clf.best_params_['C']
        print "C",C
        print clf.best_score_
        gamma=clf.best_params_['gamma']
        print "gamma",gamma
        y_predict_proba=cross_val_predict(svm.SVC(kernel='rbf',C=C,gamma=gamma,probability=True),X,Y,cv=10,method="predict_proba")
#         ROC_AUC_area="%0.4f"%cross_val_score(svm.SVC(kernel='rbf',C=C,gamma=gamma,probability=True),X,Y,cv=10,n_jobs=-1).mean()
        Y=pd.DataFrame(Y)    
        y_predict_proba=pd.DataFrame(y_predict_proba)
        y_predict_proba=pd.concat([Y,y_predict_proba],axis=1)
        pd.DataFrame(y_predict_proba).to_csv('/home01/chenhuangrong/ROC/svm_label.csv',header=None,index=False)
        # savafile = 'svm_crossvalidation_parameter.txt'
        # f = open(savafile, 'w+')
        # f.write("MCC:%f"%metrics.matthews_corrcoef(Y,y_predict)+'\n')
        # f.write("ACC:%f"%metrics.accuracy_score(Y,y_predict)+'\n')
        # f.write("ROC_AUC_AREA:%f"%ROC_AUC_area+'\n')
        # f.write("SN:%f,SP:%f,TP:%d:,TN:%d,FP:%d,FN:%d"%performance(Y,y_predict)+'\n')
        # f.write("ROC_AUC:%f"%metrics.roc_auc_score(Y,y_predict)+'\n')
        # f.write("C:%f,gamma:%f"%(C,gamma)+'\n')
        # f.write("F1-score:%f"%metrics.f1_score(Y,y_predict)+'\n')
        # f.write("F-measure:%f"%metrics.f1_score(Y,y_predict)+'\n')
        # f.close()
svm_crossvalidation()
# Out:
# C 0.578555118641
# 0.791115547926
# gamma 0.0450077042981

# %%
from sklearn import svm
import numpy as np
import pandas as pd
import math
import easy_excel
from sklearn.model_selection import *
import sklearn.ensemble
from sklearn import metrics
import sys
from sklearn.model_selection import GridSearchCV
def svm_crossvalidation():
    if __name__=='__main__':
        datapath ="/home01/chenhuangrong/ROC/PseDNC.csv"
        train_data = pd.read_csv(datapath, header=None, index_col=None)
        X = np.array(train_data)
        Y = list(map(lambda x: 1, xrange(len(train_data) / 2)))
        Y2 = list(map(lambda x: 0, xrange(len(train_data) / 2)))
        Y.extend(Y2)
        Y = np.array(Y)
        svc = svm.SVC()
#         parameters = {'kernel':['rbf'], 'C': np.linspace(2,5,2), 'gamma': np.linspace(2,5,2)}
        parameters = {'kernel': ['rbf'], 'C':np.logspace(-5,15,20,base=2), 'gamma': np.logspace(-15,5,20,base=2)}
        clf = GridSearchCV(svc, parameters, cv=10, n_jobs=-1, scoring='roc_auc')
        clf.fit(X, Y)
        C=clf.best_params_['C']
        print "C",C
        print clf.best_score_
        gamma=clf.best_params_['gamma']
        print "gamma",gamma
        y_predict_proba=cross_val_predict(svm.SVC(kernel='rbf',C=C,gamma=gamma,probability=True),X,Y,cv=10,method="predict_proba")
#         ROC_AUC_area="%0.4f"%cross_val_score(svm.SVC(kernel='rbf',C=C,gamma=gamma,probability=True),X,Y,cv=10,n_jobs=-1).mean()
        Y=pd.DataFrame(Y)    
        y_predict_proba=pd.DataFrame(y_predict_proba)
        y_predict_proba=pd.concat([Y,y_predict_proba],axis=1)
        pd.DataFrame(y_predict_proba).to_csv('/home01/chenhuangrong/ROC/PseDNC_label.csv',header=None,index=False)
        # savafile = 'svm_crossvalidation_parameter.txt'
        # f = open(savafile, 'w+')
        # f.write("MCC:%f"%metrics.matthews_corrcoef(Y,y_predict)+'\n')
        # f.write("ACC:%f"%metrics.accuracy_score(Y,y_predict)+'\n')
        # f.write("ROC_AUC_AREA:%f"%ROC_AUC_area+'\n')
        # f.write("SN:%f,SP:%f,TP:%d:,TN:%d,FP:%d,FN:%d"%performance(Y,y_predict)+'\n')
        # f.write("ROC_AUC:%f"%metrics.roc_auc_score(Y,y_predict)+'\n')
        # f.write("C:%f,gamma:%f"%(C,gamma)+'\n')
        # f.write("F1-score:%f"%metrics.f1_score(Y,y_predict)+'\n')
        # f.write("F-measure:%f"%metrics.f1_score(Y,y_predict)+'\n')
        # f.close()
svm_crossvalidation()
# Out:
# C 15797.0595503
# 0.70367329628
# gamma 0.401705613283

# %%
from sklearn import svm
import numpy as np
import pandas as pd
import math
import easy_excel
from sklearn.model_selection import *
import sklearn.ensemble
from sklearn import metrics
import sys
from sklearn.model_selection import GridSearchCV
def svm_crossvalidation():
    if __name__=='__main__':
        datapath ="/home01/chenhuangrong/ROC/PCP.csv"
        train_data = pd.read_csv(datapath, header=None, index_col=None)
        X = np.array(train_data)
        Y = list(map(lambda x: 1, xrange(len(train_data) / 2)))
        Y2 = list(map(lambda x: 0, xrange(len(train_data) / 2)))
        Y.extend(Y2)
        Y = np.array(Y)
        svc = svm.SVC()
#         parameters = {'kernel':['rbf'], 'C': np.linspace(2,5,2), 'gamma': np.linspace(2,5,2)}
        parameters = {'kernel': ['rbf'], 'C':np.logspace(-5,15,20,base=2), 'gamma': np.logspace(-15,5,20,base=2)}
        clf = GridSearchCV(svc, parameters, cv=10, n_jobs=-1, scoring='roc_auc')
        clf.fit(X, Y)
        C=clf.best_params_['C']
        print "C",C
        print clf.best_score_
        gamma=clf.best_params_['gamma']
        print "gamma",gamma
        y_predict_proba=cross_val_predict(svm.SVC(kernel='rbf',C=C,gamma=gamma,probability=True),X,Y,cv=10,method="predict_proba")
#         ROC_AUC_area="%0.4f"%cross_val_score(svm.SVC(kernel='rbf',C=C,gamma=gamma,probability=True),X,Y,cv=10,n_jobs=-1).mean()
        Y=pd.DataFrame(Y)    
        y_predict_proba=pd.DataFrame(y_predict_proba)
        y_predict_proba=pd.concat([Y,y_predict_proba],axis=1)
        pd.DataFrame(y_predict_proba).to_csv('/home01/chenhuangrong/ROC/PCP_label.csv',header=None,index=False)
        # savafile = 'svm_crossvalidation_parameter.txt'
        # f = open(savafile, 'w+')
        # f.write("MCC:%f"%metrics.matthews_corrcoef(Y,y_predict)+'\n')
        # f.write("ACC:%f"%metrics.accuracy_score(Y,y_predict)+'\n')
        # f.write("ROC_AUC_AREA:%f"%ROC_AUC_area+'\n')
        # f.write("SN:%f,SP:%f,TP:%d:,TN:%d,FP:%d,FN:%d"%performance(Y,y_predict)+'\n')
        # f.write("ROC_AUC:%f"%metrics.roc_auc_score(Y,y_predict)+'\n')
        # f.write("C:%f,gamma:%f"%(C,gamma)+'\n')
        # f.write("F1-score:%f"%metrics.f1_score(Y,y_predict)+'\n')
        # f.write("F-measure:%f"%metrics.f1_score(Y,y_predict)+'\n')
        # f.close()
svm_crossvalidation()
# Out:
# C 46.0878892012
# 0.76009697096
# gamma 0.00504273124198

# %%
from sklearn import svm
import numpy as np
import pandas as pd
import math
import easy_excel
from sklearn.model_selection import *
import sklearn.ensemble
from sklearn import metrics
import sys
from sklearn.model_selection import GridSearchCV
def svm_crossvalidation():
    if __name__=='__main__':
        datapath ="/home01/chenhuangrong/ROC/PSTNP.csv"
        train_data = pd.read_csv(datapath, header=None, index_col=None)
        X = np.array(train_data)
        Y = list(map(lambda x: 1, xrange(len(train_data) / 2)))
        Y2 = list(map(lambda x: 0, xrange(len(train_data) / 2)))
        Y.extend(Y2)
        Y = np.array(Y)
        svc = svm.SVC()
#         parameters = {'kernel':['rbf'], 'C': np.linspace(2,5,2), 'gamma': np.linspace(2,5,2)}
        parameters = {'kernel': ['rbf'], 'C':np.logspace(-5,15,20,base=2), 'gamma': np.logspace(-15,5,20,base=2)}
        clf = GridSearchCV(svc, parameters, cv=10, n_jobs=-1, scoring='roc_auc')
        clf.fit(X, Y)
        C=clf.best_params_['C']
        print "C",C
        print clf.best_score_
        gamma=clf.best_params_['gamma']
        print "gamma",gamma
        y_predict_proba=cross_val_predict(svm.SVC(kernel='rbf',C=C,gamma=gamma,probability=True),X,Y,cv=10,method="predict_proba")
#         ROC_AUC_area="%0.4f"%cross_val_score(svm.SVC(kernel='rbf',C=C,gamma=gamma,probability=True),X,Y,cv=10,n_jobs=-1).mean()
        Y=pd.DataFrame(Y)    
        y_predict_proba=pd.DataFrame(y_predict_proba)
        y_predict_proba=pd.concat([Y,y_predict_proba],axis=1)
        pd.DataFrame(y_predict_proba).to_csv('/home01/chenhuangrong/ROC/PSTNP_label.csv',header=None,index=False)
        # savafile = 'svm_crossvalidation_parameter.txt'
        # f = open(savafile, 'w+')
        # f.write("MCC:%f"%metrics.matthews_corrcoef(Y,y_predict)+'\n')
        # f.write("ACC:%f"%metrics.accuracy_score(Y,y_predict)+'\n')
        # f.write("ROC_AUC_AREA:%f"%ROC_AUC_area+'\n')
        # f.write("SN:%f,SP:%f,TP:%d:,TN:%d,FP:%d,FN:%d"%performance(Y,y_predict)+'\n')
        # f.write("ROC_AUC:%f"%metrics.roc_auc_score(Y,y_predict)+'\n')
        # f.write("C:%f,gamma:%f"%(C,gamma)+'\n')
        # f.write("F1-score:%f"%metrics.f1_score(Y,y_predict)+'\n')
        # f.write("F-measure:%f"%metrics.f1_score(Y,y_predict)+'\n')
        # f.close()
svm_crossvalidation()
# Out:
# C 198.30523421
# 0.886919253615
# gamma 0.193657455283

# %%
from sklearn import svm

import numpy as np
import pandas as pd
import math
import easy_excel
from sklearn.model_selection import *
import sklearn.ensemble
from sklearn import metrics
import sys
from sklearn.model_selection import GridSearchCV
def performance(labelArr, predictArr):
    #labelArr[i] is actual value,predictArr[i] is predict value
    TP = 0.; TN = 0.; FP = 0.; FN = 0.
    for i in range(len(labelArr)):
        if labelArr[i] == 1 and predictArr[i] == 1:
            TP += 1.
        if labelArr[i] == 1 and predictArr[i] == 0:
            FN += 1.
        if labelArr[i] == 0 and predictArr[i] == 1:
            FP += 1.
        if labelArr[i] == 0 and predictArr[i] == 0:
            TN += 1.
    SN = TP/(TP + FN) #Sensitivity = TP/P  and P = TP + FN
    SP = TN/(FP + TN) #Specificity = TN/N  and N = TN + FP
    precision=TP/(TP+FP)
    recall=TP/(TP+FN)
    GM=math.sqrt(recall*SP)
    #MCC = (TP*TN-FP*FN)/math.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))
    return precision,recall,SN,SP,GM,TP,TN,FP,FN

def svm_crossvalidation():
    if __name__=='__main__':
        datapath ='/home01/chenhuangrong/ROC/%d_interval_PSTNP.csv'%kk
        train_data = pd.read_csv(datapath, header=None, index_col=None)
        X = np.array(train_data)
        Y = list(map(lambda x: 1, xrange(len(train_data) / 2)))
        Y2 = list(map(lambda x: 0, xrange(len(train_data) / 2)))
        Y.extend(Y2)
        Y = np.array(Y)
        svc = svm.SVC()
#         parameters = {'kernel':['rbf'], 'C': np.linspace(1,50,50), 'gamma': np.linspace(0.77,0.80,100)}
#         parameters = {'kernel': ['rbf'], 'C':np.logspace(-5,15,20,base=2), 'gamma': np.logspace(-15,-5,20,base=2)}
#         parameters = {'kernel': ['rbf'], 'C':map(lambda x:2**x,xrange(-2,5,1)), 'gamma':map(lambda x:2**x,xrange(-5,2,1))}
        parameters = {'kernel': ['rbf'], 'C':map(lambda x:2**x,np.linspace(-2,5,28)), 'gamma':map(lambda x:2**x,np.linspace(-5,2,28))}
#         parameters = {'kernel': ['rbf'], 'C':np.linspace(3,5,10), 'gamma': np.linspace(0.05,0.07,10)}
        clf = GridSearchCV(svc, parameters, cv=10, n_jobs=-1, scoring='accuracy')
        clf.fit(X, Y)
        C=clf.best_params_['C']
        print clf.best_score_
        gamma=clf.best_params_['gamma']
        y_predict=cross_val_predict(svm.SVC(kernel='rbf',C=C,gamma=gamma),X,Y,cv=10,n_jobs=-1)
        
        
        
        ROC_AUC_area="%0.4f"%cross_val_score(svm.SVC(kernel='rbf',C=C,gamma=gamma),X,Y,cv=10,n_jobs=-1).mean()
        ACC=metrics.accuracy_score(Y,y_predict)
        precision, recall, SN, SP, GM, TP, TN, FP, FN = performance(Y, y_predict)
        F1_Score=metrics.f1_score(Y, y_predict)
        F_measure=F1_Score
        MCC=metrics.matthews_corrcoef(Y, y_predict)
        pos=TP+FN
        neg=FP+TN
        savedata=[[['svm'+"C:"+str(C)+"gamma:"+str(gamma),ACC,precision, recall,SN, SP, GM,F_measure,F1_Score,MCC,ROC_AUC_area,TP,FN,FP,TN,pos,neg]]]
        print savedata
        easy_excel.save("svm_crossvalidation",[str(X.shape[1])],savedata,'/home01/chenhuangrong/ROC/%d_interval_PSTNP_result.xls'%kk)
        
        y_predict_proba=cross_val_predict(svm.SVC(kernel='rbf',C=C,gamma=gamma,probability=True),X,Y,cv=10,method="predict_proba")
        Y=pd.DataFrame(Y)    
        y_predict_proba=pd.DataFrame(y_predict_proba)
        y_predict_proba=pd.concat([Y,y_predict_proba],axis=1)
        pd.DataFrame(y_predict_proba).to_csv('/home01/chenhuangrong/ROC/%d_interval_PSTNP_label.csv'%kk,header=None,index=False)
        
        y_predict=pd.DataFrame(y_predict)
        y_predict_=pd.concat([Y,y_predict],axis=1)
        pd.DataFrame(y_predict_).to_csv('/home01/chenhuangrong/ROC/%d_interval_PSTNP_predict.csv'%kk,header=None,index=False)
        # savafile = 'svm_crossvalidation_parameter.txt'
        # f = open(savafile, 'w+')
        # f.write("MCC:%f"%metrics.matthews_corrcoef(Y,y_predict)+'\n')
        # f.write("ACC:%f"%metrics.accuracy_score(Y,y_predict)+'\n')
        # f.write("ROC_AUC_AREA:%f"%ROC_AUC_area+'\n')
        # f.write("SN:%f,SP:%f,TP:%d:,TN:%d,FP:%d,FN:%d"%performance(Y,y_predict)+'\n')
        # f.write("ROC_AUC:%f"%metrics.roc_auc_score(Y,y_predict)+'\n')
        # f.write("C:%f,gamma:%f"%(C,gamma)+'\n')
        # f.write("F1-score:%f"%metrics.f1_score(Y,y_predict)+'\n')
        # f.write("F-measure:%f"%metrics.f1_score(Y,y_predict)+'\n')
        # f.close()
kk=1
for kk in xrange(1,6):
    svm_crossvalidation()
# Out:
# 0.754781943382
# [[['svmC:26.736537569gamma:0.22560201395', 0.75478194338179039, 0.7561538461538462, 0.7521040550879877, 0.7521040550879877, 0.7574598316755929, 0.7547771929314492, 0.75412351361718444, 0.75412351361718444, 0.50957119517342642, '0.7547', 983.0, 324.0, 317.0, 990.0, 1307.0, 1307.0]]]
# 0.770466717674
# [[['svmC:32.0gamma:0.157490131237', 0.77046671767406272, 0.7725520431765613, 0.7666411629686305, 0.7666411629686305, 0.774292272379495, 0.7704572202105966, 0.76958525345622131, 0.76958525345622131, 0.54094926902301632, '0.7704', 1002.0, 305.0, 295.0, 1012.0, 1307.0, 1307.0]]]
# 0.811400153022
# [[['svmC:9.09570324078gamma:2.79235328585', 0.81140015302218826, 0.8174726989079563, 0.8018362662586075, 0.8018362662586075, 0.8209640397857689, 0.811343786809515, 0.80957898802626493, 0.80957898802626493, 0.62291426982705156, '0.8113', 1048.0, 259.0, 234.0, 1073.0, 1307.0, 1307.0]]]
# 0.911629686305
# ...

# %%
from sklearn import svm

import numpy as np
import pandas as pd
import math
import easy_excel
from sklearn.model_selection import *
import sklearn.ensemble
from sklearn import metrics
import sys
from sklearn.model_selection import GridSearchCV
def performance(labelArr, predictArr):
    #labelArr[i] is actual value,predictArr[i] is predict value
    TP = 0.; TN = 0.; FP = 0.; FN = 0.
    for i in range(len(labelArr)):
        if labelArr[i] == 1 and predictArr[i] == 1:
            TP += 1.
        if labelArr[i] == 1 and predictArr[i] == 0:
            FN += 1.
        if labelArr[i] == 0 and predictArr[i] == 1:
            FP += 1.
        if labelArr[i] == 0 and predictArr[i] == 0:
            TN += 1.
    SN = TP/(TP + FN) #Sensitivity = TP/P  and P = TP + FN
    SP = TN/(FP + TN) #Specificity = TN/N  and N = TN + FP
    precision=TP/(TP+FP)
    recall=TP/(TP+FN)
    GM=math.sqrt(recall*SP)
    #MCC = (TP*TN-FP*FN)/math.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))
    return precision,recall,SN,SP,GM,TP,TN,FP,FN
def svm_crossvalidation():
    if __name__=='__main__':
        datapath ='/home01/chenhuangrong/ROC/3_interval_PSTNP.csv'
        train_data = pd.read_csv(datapath, header=None, index_col=None)
        X = np.array(train_data)
        Y = list(map(lambda x: 1, xrange(len(train_data) / 2)))
        Y2 = list(map(lambda x: 0, xrange(len(train_data) / 2)))
        Y.extend(Y2)
        Y = np.array(Y)
        y_predict=cross_val_predict(svm.SVC(kernel='rbf',C=11.3137,gamma=2),X,Y,cv=10,n_jobs=-1)
        ROC_AUC_area="%0.4f"%cross_val_score(svm.SVC(kernel='rbf',C=11.3137,gamma=2),X,Y,cv=10,n_jobs=-1).mean()
        ACC=metrics.accuracy_score(Y,y_predict)
        precision, recall, SN, SP, GM, TP, TN, FP, FN = performance(Y, y_predict)
        F1_Score=metrics.f1_score(Y, y_predict)
        F_measure=F1_Score
        MCC=metrics.matthews_corrcoef(Y, y_predict)
        pos=TP+FN
        neg=FP+TN
        savedata=[[['svm'+"C:"+str(11.3137)+"gamma:"+str(2),ACC,precision, recall,SN, SP, GM,F_measure,F1_Score,MCC,ROC_AUC_area,TP,FN,FP,TN,pos,neg]]]
        print savedata
        easy_excel.save("svm_crossvalidation",[str(X.shape[1])],savedata,'/home01/chenhuangrong/ROC/3_interval_PSTNP_result3.xls')

        # savafile = 'svm_crossvalidation_parameter.txt'
        # f = open(savafile, 'w+')
        # f.write("MCC:%f"%metrics.matthews_corrcoef(Y,y_predict)+'\n')
        # f.write("ACC:%f"%metrics.accuracy_score(Y,y_predict)+'\n')
        # f.write("ROC_AUC_AREA:%f"%ROC_AUC_area+'\n')
        # f.write("SN:%f,SP:%f,TP:%d:,TN:%d,FP:%d,FN:%d"%performance(Y,y_predict)+'\n')
        # f.write("ROC_AUC:%f"%metrics.roc_auc_score(Y,y_predict)+'\n')
        # f.write("C:%f,gamma:%f"%(C,gamma)+'\n')
        # f.write("F1-score:%f"%metrics.f1_score(Y,y_predict)+'\n')
        # f.write("F-measure:%f"%metrics.f1_score(Y,y_predict)+'\n')
        # f.close()
svm_crossvalidation()
# Out:
# [[['svmC:11.3137gamma:2', 0.81025248661055849, 0.8175411119812059, 0.7987758224942617, 0.7987758224942617, 0.8217291507268554, 0.8101712030425143, 0.80804953560371529, 0.80804953560371529, 0.62066849599834184, '0.8102', 1044.0, 263.0, 233.0, 1074.0, 1307.0, 1307.0]]]

# %%
from sklearn import svm

import numpy as np
import pandas as pd
import math
import easy_excel
from sklearn.model_selection import *
import sklearn.ensemble
from sklearn import metrics
import sys
from sklearn.model_selection import GridSearchCV
def svm_crossvalidation():
    if __name__=='__main__':
        datapath ='/home01/chenhuangrong/ROC/3_interval_PSTNP.csv'
        train_data = pd.read_csv(datapath, header=None, index_col=None)
        X = np.array(train_data)
        Y = list(map(lambda x: 1, xrange(len(train_data) / 2)))
        Y2 = list(map(lambda x: 0, xrange(len(train_data) / 2)))
        Y.extend(Y2)
        Y = np.array(Y)
        y_predict=cross_val_predict(svm.SVC(kernel='rbf',C=11.3137,gamma=2),X,Y,cv=10,n_jobs=-1)
        y_predict=pd.DataFrame(y_predict)
        Y=pd.DataFrame(Y)
        YY=pd.concat([Y,y_predict],axis=1)
        pd.DataFrame(YY).to_csv('/home01/chenhuangrong/ROC/vote_3_interval_PSTNP.csv',header=None,index=False)
        
svm_crossvalidation()

# %%
from sklearn import svm

import numpy as np
import pandas as pd
import math
import easy_excel
from sklearn.model_selection import *
import sklearn.ensemble
from sklearn import metrics
import sys
from sklearn.model_selection import GridSearchCV
k=5
datapath=[[]]*k
data=[[]]*k

for i in xrange(5):
    datapath[i]='/home01/chenhuangrong/ROC/vote_%d_interval_PSTNP.csv'%(i+1)
    data[i]=pd.read_csv(datapath,header=None,index=False)
for i in xrange(2):
    for j in xrange(2):
        for k in xrange(2):
            for q in xrange(2):
                for t in xrange(2):
                    final_data=np.matrix(data[1])*i+np.matrix(data[2])*j+np.matrix(data[3])*k+np.matrix(data[4])*q+np.matrix(data[5])*t
                    final_data/=k
                    for i,line_data in enumerate(final_data):
                        for j,code_date in enumerate(line_data):
                            if final_data[i][j]>0.5:
                                 final_data[i][j]=1
                            else:
                                 final_data[i][j]=0
                    ACC=metrics.accuracy_score(Y,y_predict)
                    precision, recall, SN, SP, GM, TP, TN, FP, FN = performance(Y, y_predict)
                    F1_Score=metrics.f1_score(Y, y_predict)
                    F_measure=F1_Score
                    MCC=metrics.matthews_corrcoef(Y, y_predict)
                    pos=TP+FN
                    neg=FP+TN
                    savedata=[[['svm'+"C:"+str(11.3137)+"gamma:"+str(2),ACC,precision, recall,SN, SP, GM,F_measure,F1_Score,MCC,ROC_AUC_area,TP,FN,FP,TN,pos,neg]]]
                    print savedata
                    easy_excel.save("svm_crossvalidation",[str(X.shape[1])],savedata,'/home01/chenhuangrong/ROC/vote_result.xls')
# Out:
# /home01/chenhuangrong/ROC/vote_1_interval_PSTNP.csv
# /home01/chenhuangrong/ROC/vote_2_interval_PSTNP.csv
# /home01/chenhuangrong/ROC/vote_3_interval_PSTNP.csv
# /home01/chenhuangrong/ROC/vote_4_interval_PSTNP.csv
# /home01/chenhuangrong/ROC/vote_5_interval_PSTNP.csv

# %%
print(__doc__)

import numpy as np
from scipy import interp
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import StratifiedKFold

data=pd.read_csv("/home01/chenhuangrong/ROC/svm_label.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr,linestyle='--', lw=2, color='r',alpha=0.3,label='svm(ROC =%f)'%roc_auc)
# plt.plot(fpr, tpr,linestyle='g-', lw=1,alpha=0.3,label='svm(ROC =%f)'%roc_auc)
plt.plot(fpr, tpr,'g+',fpr, tpr,'r-')

plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %%
import pandas as pd
import numpy as np
import itertools
seq=[]
m6a_2614_sequence="/home01/chenhuangrong/ROC/m6a_data.txt"
RNA_code='ACGU'
k=5
fh=open(m6a_2614_sequence)
for line in fh:
    if line.startswith('>'):
        continue
    else:
        seq.append(line.replace('\n',''))
fh.close()

def make_kmer_list(k, alphabet):
    try:
        return ["".join(e) for e in itertools.product(alphabet, repeat=k)]
    except TypeError:
        print("TypeError: k must be an inter and larger than 0, alphabet must be a string.")
        raise TypeError
    except ValueError:
        print("TypeError: k must be an inter and larger than 0")
        raise ValueError
positive_seq=seq[:len(seq)/2]
negative_seq=seq[len(seq)/2:]

for interval in xrange(1,k+1):
    final_seq_value=[[0 for ii in xrange(len(seq[0])-interval)] for jj in xrange(len(seq))]
    code_values=make_kmer_list(interval,RNA_code)
    code_len=len(code_values)
    
    positive_seq_value=[[0 for jj in xrange(len(seq[0])-1)] for ii in xrange(code_len)]
    negative_seq_value=[[0 for jj in xrange(len(seq[0])-1)] for ii in xrange(code_len)]
    for i,line_value in enumerate(positive_seq):
        for j,code_value in enumerate(line_value):
            if j<= len(line_value)-interval-1 :
                for p,c_value in enumerate(code_values):
                    if c_value==line_value[j:j+interval]:
                        positive_seq_value[p][j]+=1
    positive_seq_value=np.matrix(positive_seq_value)*1.0/(len(seq)/2)
    for i,line_value in enumerate(negative_seq):
        for j,code_value in enumerate(line_value):
            if j<= len(line_value)-interval-1 :
                for p,c_value in enumerate(code_values):
                    if c_value==line_value[j:j+interval]:
                        negative_seq_value[p][j]+=1
    negative_seq_value=np.matrix(negative_seq_value)*1.0/(len(seq)/2)
    for i,line_value in enumerate(seq):
        for j,code_value in enumerate(line_value):
            if j<= len(line_value)-interval-1 :
                for p,c_value in enumerate(code_values):
                    if c_value==line_value[j:j+interval]:
                          final_seq_value[i][j]=positive_seq_value[p,j]-negative_seq_value[p,j]
#     print positive_seq_value,negative_seq_value
#     break
    pd.DataFrame(final_seq_value).to_csv('/home01/chenhuangrong/ROC/%d_interval_PSTNP.csv'%interval,header=None,index=False)

# %%
print(__doc__)

import numpy as np
from scipy import interp
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import StratifiedKFold

data=pd.read_csv("/home01/chenhuangrong/ROC/svm_label.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
# plt.plot(fpr, tpr,linestyle='--', lw=2, color='r',alpha=0.3,label='svm(ROC =%f)'%roc_auc)
# plt.plot(fpr, tpr,linestyle='g-', lw=1,alpha=0.3,label='svm(ROC =%f)'%roc_auc)
plt.plot(fpr, tpr,'g--',label='RFH(ROC =%f)'%roc_auc)

data=pd.read_csv("/home01/chenhuangrong/ROC/PSTNP_label.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'r-',label='PSTNP(ROC =%f)'%roc_auc)

data=pd.read_csv("/home01/chenhuangrong/ROC/PseDNC_label.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'b-.',label='PseDNC(ROC =%f)'%roc_auc)

data=pd.read_csv("/home01/chenhuangrong/ROC/PCP_label.csv",header=None,index_col=None)
fpr, tpr, thresholds = roc_curve(data.values[:,0], data.values[:, 2])
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr,'k,',label='PCP(ROC =%f)'%roc_auc)

plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Automatically created module for IPython interactive environment
